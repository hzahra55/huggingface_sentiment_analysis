# %%
# !pip install tensorflow

# %%
# !pip install transformers

# %%
import tensorflow as tf

# %%
import transformers

# %%
print(tf.__version__)
# Out:
# 2.17.1

# %%
from transformers import pipeline

# %%
classifier = pipeline(task='sentiment-analysis', model= 'ProsusAI/finbert')
# Out:
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
classifier('lovely')
# Out:
# [{'label': 'neutral', 'score': 0.8896016478538513}]

# %%
classifier2 = pipeline(task='text-classification', model='SamLowe/roberta-base-go_emotions', top_k=None)
# Out:
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# Device set to use cpu

# %%
classifier2('hate this')
# Out:
# [[{'label': 'anger', 'score': 0.7591540813446045},
#   {'label': 'annoyance', 'score': 0.1759783923625946},
#   {'label': 'disapproval', 'score': 0.1036292240023613},
#   {'label': 'neutral', 'score': 0.043461672961711884},
#   {'label': 'disgust', 'score': 0.0386117622256279},
#   {'label': 'disappointment', 'score': 0.01332949846982956},
#   {'label': 'sadness', 'score': 0.012502268888056278},
#   {'label': 'confusion', 'score': 0.007614324800670147},
#   {'label': 'curiosity', 'score': 0.007525656837970018},
#   {'label': 'approval', 'score': 0.006118810269981623},
#   {'label': 'love', 'score': 0.005196989979594946},
#   {'label': 'admiration', 'score': 0.003911149222403765},
#   {'label': 'caring', 'score': 0.0036805435083806515},
#   {'label': 'realization', 'score': 0.0031750150956213474},
#   {'label': 'gratitude', 'score': 0.0031672674231231213},
#   {'label': 'optimism', 'score': 0.0029250080697238445},
#   {'label': 'embarrassment', 'score': 0.0027051225770264864},
# ...

# %%
# Summarization

# %%
summarizer = pipeline(task = 'summarization', model='facebook/bart-large-cnn')
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
text = 'This lab manual has been prepared to facilitate the students of Computer Software Engineering in studying and analyzing various tools and concepts of Machine Learning. Generally, Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy. Machine learning is an important component of the growing field of data science. Through the use of statistical methods, algorithms are trained to make classifications or predictions, uncovering key insights within data mining projects. These insights subsequently drive decision making within applications and businesses, ideally impacting key growth metrics. As big data continues to expand and grow, the market demand for data scientists will increase, requiring them to assist in the identification of the most relevant business questions and subsequently the data to answer them.  Students will be able to understand the underlying mathematical relationships within and across Machine Learning algorithms'

# %%
sum_text = summarizer(text, min_length=5, max_length=140)[0]['summary_text']

# %%
sum_text= summarizer(text, min_length = 5, max_length= 140)[0]['summary_text']

# %%
sum_text
# Out:
# 'Machine learning is a branch of artificial intelligence (AI) and computer science. It focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy. Machine learning is an important component of the growing field of data science.'

# %%
classifier2(sum_text)
# Out:
# [[{'label': 'neutral', 'score': 0.6866545677185059},
#   {'label': 'approval', 'score': 0.29408034682273865},
#   {'label': 'realization', 'score': 0.06299931555986404},
#   {'label': 'admiration', 'score': 0.034677524119615555},
#   {'label': 'optimism', 'score': 0.006325951311737299},
#   {'label': 'annoyance', 'score': 0.005546709522604942},
#   {'label': 'disappointment', 'score': 0.0025421292521059513},
#   {'label': 'disapproval', 'score': 0.002341595711186528},
#   {'label': 'excitement', 'score': 0.0021807244047522545},
#   {'label': 'disgust', 'score': 0.0019027349771931767},
#   {'label': 'confusion', 'score': 0.0016722038853913546},
#   {'label': 'love', 'score': 0.0015957093564793468},
#   {'label': 'pride', 'score': 0.001350478851236403},
#   {'label': 'joy', 'score': 0.001320253242738545},
#   {'label': 'surprise', 'score': 0.0013049676781520247},
#   {'label': 'relief', 'score': 0.0010794592089951038},
#   {'label': 'curiosity', 'score': 0.0010004815412685275},
# ...

# %%
# conversational_text

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/blenderbot-400M-distill")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/blenderbot-400M-distill")

# %%
chatbot = pipeline(task='text2text-generation', model= 'facebook/blenderbot-400M-distill')
# Out:
# Device set to use cpu

# %%
input = 'Hi i am zahra, how are you?'

# %%
# tokenize input

# %%
tokens = tokenizer(input,return_tensors='pt')

# %%
# get response

# %%
reply = model.generate(**tokens)

# %%
# decode reply

# %%
response = tokenizer.decode(reply[0])

# %%
response
# Out:
# "<s> I'm doing well. How are you doing this evening? I'm just hanging out with my cat.</s>"

# %%
tokens = tokenizer('where do you live?',return_tensors='pt')

# %%
reply = model.generate(**tokens)

# %%
response = tokenizer.decode(reply[0])

# %%
response
# Out:
# "<s> I live in North Carolina. It's hot and humid here. How about you?</s>"
